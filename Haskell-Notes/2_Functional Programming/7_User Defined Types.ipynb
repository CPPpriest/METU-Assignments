-- %% [markdown]
-- ## User Defined Types
--
-- In Haskell new data types can be defined by `type` and `data` keywords.
--
-- - `type` -> define aliases to existing types
--
-- - `data` -> creates new data types with **type constructor tags** and disjoint union operation.

-- %%
type Person = (String, Integer, Bool)

data WState = Sunny | PartClouds| Clouds | LightRain| Rain | LightSnow | Snow | IceRain    deriving (Show,Eq)  -- this part is just for Haskell to show the values, no other meaning

type Forecast = (WState, Float, Float)


today = (Rain, -1.5 , 10)

nextday = (PartClouds, 0, 12)::Forecast   -- ::Forecast specifies the data type

:t today

:t nextday

today == nextday
-- Out:
-- today :: forall {b} {c}. (Fractional b, Num c) => (WState, b, c)
-- nextday :: Forecast
-- False

-- %% [markdown]
-- Person and Forecast are `type equivalent` :
--
-- They can be used in the same pattern matching, equality checks etc...even though they are not the same type
